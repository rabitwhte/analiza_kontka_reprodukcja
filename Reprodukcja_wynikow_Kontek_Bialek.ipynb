# %% [markdown]
# Autor: Jakub Białek
#
# W związku z faktem, że dr. Krzysztof Kontek "ma prawo jako badacz do szukania anomalii tylko w jedną stronę", ja poczułem się w obowiązku sprawdzić co będzie jeśli zastosujemy tę samą metodologię dla obu kandydatów. W związku z tym, że p. Kontek nie podzielił się kodem, napisałem go sam. Głównym pytaniem jakie stawia ta analiza jest więc: czy stosując te same definicje anomalii dla obu kandydatów, metodologia wskaże podobną liczbę komisji, w których doszło do nadużyć? Odpowiedź jest twierdząca.
#
# Pewna różnica wyników jest efektem różnic w sposobie grupowanie komisji - próbowałem odtworzyć to co opisał p. Kontek, ale opisany algorytm jest niejednoznaczny. Grupy, które składają się z komisji o tym samem kodzie pocztowym będą identyczne. Różnice pojawią się w łączeniu komisji o różnych kodach. Różnice te nie powinny mieć wpływu na odpowiedź na główne pytanie tej analizy -w końcu obaj kandydaci byli analizowani w tych samych grupach, z których znaczna część pokrywała się z grupami Kontka.
#
# Serdecznie zapraszam wszystkich kolegów z branży do weryfikacji i poprawek tej analizy - w końcu nikt nie jest nieomylny. Sprawdzałem poszczególne obliczenia "na piechotę" dla danego wycinka danych i wyniki się zgadzały, ale nadal potrzebna jest druga para oczu.

# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', 100)

# %% [markdown]
# #### Wczytanie danych o obwodach, czyszczenie, grupowanie

# %%
obwody = pd.read_csv('./obwody_glosowania_utf8.csv', sep=';')

# %%
obwody = obwody[['Gmina','TERYT gminy','Numer', 'Kod pocztowy', 'Typ obszaru', 'Wyborcy']]

# %%
obwody['Typ obszaru'].unique()
# Out:
# array(['miasto', 'wieś', 'miasto i wieś', 'dzielnica w m.st. Warszawa',
#        'statek', 'zagranica'], dtype=object)

# %%
# usuń statek i zagranicę
obwody = obwody[obwody['Typ obszaru'].isin(('miasto', 'wieś', 'miasto i wieś', 'dzielnica w m.st. Warszawa'))]

# %%
obwody = obwody.dropna()

# %%
obwody.head(2)
# Out:
#             Gmina  TERYT gminy  Numer Kod pocztowy Typ obszaru  Wyborcy
# 0  m. Bolesławiec      20101.0      1       59-700      miasto   1637.0
# 1  m. Bolesławiec      20101.0      2       59-700      miasto   1286.0

# %% [markdown]
# ### Klastrowanie
#
# Z artykułu:
# 1. Początkowe grupowanie oparto na pierwszych dwóch cyfrach kodu pocztowego (np. „30” dla obszaru Krakowa).
# 2. Jeżeli powstała grupa zawierała od 10 do 16 komisji, została zaakceptowana bez zmian.
# 3. Grupy liczące mniej niż 10 komisji odłożono do późniejszego łączenia.
# 4. Grupy przekraczające 16 komisji dzielono rekurencyjnie, dodając kolejne cyfry kodu
#     pocztowego (np. z „30” → „301” → „3011” i dalej, aż do pełnych pięciu cyfr).
# 5. Pozostałe małe grupy łączono z najbliższymi sąsiadami mającymi ten sam prefiks, przy czym
#     priorytetem była ciągłość przestrzenna i zrównoważona liczebność grup.
#     W odróżnieniu od wcześniejszego podejścia, które dopuszczało grupy o wielkości 10–25 komisji,
#     niniejsze badanie przyjęło węższy zakres docelowy: od 10 do 16 komisji na grupę
#
#
# Komentarz: Algorytm z artykułu nie jest deterministyczny (niejednoznacznie wskazuje co się dzieje z grupami liczącymi mniej niż 10 komisji do ponownego połączenia) nie da się go więc odtworzyć na podstawie jego opisu. Dlatego właśnie rzetelne artykułu zawierają kod źródłowy umożliwiający reprodukcję. Autor nie podzielił się ani kodem, ani grupowaniem. Jeśli to zrobi, zaktualizuję grupowanie.
#
# Na szczęście nie powinno mieć to większego znaczenia dla celu tej analizy - a jest nim sprawdzenie czy metodologia Kontka wskazuje również anomalie na korzyść Trzaskowskiego i jaka jest ich skala.

# %%
import pandas as pd
from collections import defaultdict

def assign_groups(df: pd.DataFrame,
                  code_col: str = "kod",
                  min_size: int = 10,
                  max_size: int = 16,
) -> pd.DataFrame:
    """
    Zwraca kopię df z nową kolumną `group_id` zawierającą numer grupy
    spełniającej warunki 10 ≤ n ≤ 16.
    """

    work = df.copy()
    work["_code_str"] = work[code_col].astype(str).str.zfill(5)

    accepted = {}                # {prefix: list[index]}
    small     = {}               # prefixy < min_size (do późniejszego łączenia)

    # 1. Rekurencyjne dzielenie dużych grup
    def split(prefix: str, idxs: list[int], depth: int):
        size = len(idxs)

        # a) gotowa grupa
        if min_size <= size <= max_size or depth == 5:
            accepted[prefix] = idxs
            return
        # b) za mała – zapisz do późniejszego łączenia
        if size < min_size:
            small[prefix] = idxs
            return
        # c) za duża – dziel głębiej
        next_depth = depth + 1
        sub_prefixes = work.loc[idxs, "_code_str"].str[:next_depth]
        for sub_pref, sub_idxs in work.loc[idxs].groupby(sub_prefixes).groups.items():
            split(sub_pref, list(sub_idxs), next_depth)

    # start od 2-cyfrowych
    for pref2, grp in work.groupby(work["_code_str"].str[:2]).groups.items():
        split(pref2, list(grp), depth=2)

    # 2. Łączenie małych grup w obrębie tych samych 2-cyfrowych prefiksów
    buckets = defaultdict(list)          # {pref2: [(pref, idxs), ...]}
    for p, idxs in small.items():
        buckets[p[:2]].append((p, idxs))

    for pref2, lst in buckets.items():
        # uporządkuj rosnąco wg wartości prefiksu → przybliżenie "sąsiedztwa"
        lst.sort(key=lambda x: int(x[0]))
        buf_idx, buf_pref = [], []

        for p, idxs in lst:
            buf_idx.extend(idxs)
            buf_pref.append(p)

            if len(buf_idx) >= min_size:
                # jeśli przypadkiem > max_size, tnij w kawałki
                while len(buf_idx) > max_size:
                    accepted[f"{pref2}_{len(accepted)}"] = buf_idx[:max_size]
                    buf_idx = buf_idx[max_size:]
                accepted["+".join(buf_pref)] = buf_idx
                buf_idx, buf_pref = [], []

        # resztka < 10 – dociągamy do ostatniej grupy z tego prefiksu
        if buf_idx:
            *_, last_key = [k for k in accepted.keys() if k.startswith(pref2)]
            accepted[last_key].extend(buf_idx)

    # 3. Ostateczne przypisanie numerów
    idx2gid = {}
    for gid, (_, lst) in enumerate(accepted.items()):
        for i in lst:
            idx2gid[i] = gid

    work["group_id"] = work.index.map(idx2gid)

    return work.drop(columns="_code_str")

# %%
obwody['kod'] = obwody['Kod pocztowy'].str.replace('-','').astype(int) 
obwody = assign_groups(obwody, code_col='kod')

# %% [markdown]
# Z artykułu:
#
# "Większość grup spełniła założony docelowy rozmiar: 1 386 grup (62,8%) zawierało od 10 do 16
# komisji, a 2 017 grup (91,3%) zawierało od 6 do 30 komisji. Większe grupy zazwyczaj odpowiadały 5
# obszarom miejskim — na przykład takim jak Toruń czy Włocławek, gdzie pojedynczy kod pocztowy
# obejmował całe miasto"

# %%
# między 10 a 16
sum((obwody['group_id'].value_counts()>=10) & (obwody['group_id'].value_counts()<=16))
# Out:
# 1223

# %%
# między 6 a 30
sum((obwody['group_id'].value_counts()>=6) & (obwody['group_id'].value_counts()<=30))
# Out:
# 1925

# %%
# duże grupy
obwody[obwody['group_id']==2150]
# Out:
#          Gmina  TERYT gminy  Numer Kod pocztowy Typ obszaru  Wyborcy    kod  \
# 4100  m. Toruń      46301.0      1       87-100      miasto   1579.0  87100
# 4101  m. Toruń      46301.0      2       87-100      miasto   1767.0  87100
# 4102  m. Toruń      46301.0      3       87-100      miasto    649.0  87100
# 4103  m. Toruń      46301.0      4       87-100      miasto   1839.0  87100
# 4104  m. Toruń      46301.0      5       87-100      miasto   1404.0  87100
# ...        ...          ...    ...          ...         ...      ...    ...
# 4221  m. Toruń      46301.0    122       87-100      miasto     68.0  87100
# 4222  m. Toruń      46301.0    123       87-100      miasto     46.0  87100
# 4223  m. Toruń      46301.0    124       87-100      miasto    121.0  87100
# 4224  m. Toruń      46301.0    125       87-100      miasto     31.0  87100
# 4225  m. Toruń      46301.0    126       87-100      miasto    227.0  87100
#
#       group_id
# 4100      2150
# 4101      2150
# 4102      2150
# 4103      2150
# 4104      2150
# ...        ...
# 4221      2150
# 4222      2150
# 4223      2150
# 4224      2150
# 4225      2150
#
# [126 rows x 8 columns]

# %%
# usun grupy mniej niz 3-komisjowe
obwody['liczba komisji w grupie']  = obwody.groupby('group_id').transform('count')['kod']
obwody = obwody[obwody['liczba komisji w grupie']>3]

# %%
len(obwody)
# Out:
# 30553

# %% [markdown]
# # Wyniki głosowania

# %%
#https://wybory.gov.pl/prezydent2025/pl/dane_w_arkuszach
p = pd.read_csv('./protokoly_po_obwodach_utf8.csv', sep=';')
d = pd.read_csv('./protokoly_po_obwodach_w_drugiej_turze_utf8.csv', sep=';')

# %%
keep = ['Teryt Gminy', 'Nr komisji', 'Gmina', 'TRZASKOWSKI Rafał Kazimierz', 'NAWROCKI Karol Tadeusz']

# %%
p = p[keep].dropna()
d = d[keep].dropna()

# %%
p.head(2)
# Out:
#    Teryt Gminy  Nr komisji           Gmina  TRZASKOWSKI Rafał Kazimierz  \
# 0      20101.0           1  m. Bolesławiec                        361.0
# 1      20101.0           2  m. Bolesławiec                        381.0
#
#    NAWROCKI Karol Tadeusz
# 0                   287.0
# 1                   228.0

# %% [markdown]
# Łączymy wyniki z 1 i 2 tury, oznaczamy odpowiednio suffixem _1, _2.

# %%
df = pd.merge(
    left=p, 
    right=d,
    how='inner',
    left_on=['Teryt Gminy', 'Nr komisji'],
    right_on=['Teryt Gminy', 'Nr komisji'],
    suffixes = ('_1', '_2')
)

# %%
df.head(2)
# Out:
#    Teryt Gminy  Nr komisji         Gmina_1  TRZASKOWSKI Rafał Kazimierz_1  \
# 0      20101.0           1  m. Bolesławiec                          361.0
# 1      20101.0           2  m. Bolesławiec                          381.0
#
#    NAWROCKI Karol Tadeusz_1         Gmina_2  TRZASKOWSKI Rafał Kazimierz_2  \
# 0                     287.0  m. Bolesławiec                          596.0
# 1                     228.0  m. Bolesławiec                          517.0
#
#    NAWROCKI Karol Tadeusz_2
# 0                     582.0
# 1                     386.0

# %%
# polacz z obwodami

# %%
df = pd.merge(
    left=df, 
    right=obwody,
    how='inner',
    left_on=['Teryt Gminy', 'Nr komisji'],
    right_on=['TERYT gminy', 'Numer'],
)

# %%
from copy import copy
df = copy(df.dropna())

# %% [markdown]
# # Reprodukcja Analizy z artykułu dla obu kandydatów

# %% [markdown]
# ## 1. Nadmierne poparcie dla Karola Nawrockiego (względem mediany w ramach lokalnej grupy)
#
# Za artykułem: w ramach każdej grupy obliczono mediany oraz odchylenia bezwzględne od mediany (MAD), dla każdej komisji obliczono wskaźnik odchylenia od mediany
#
# $k=\frac{X-mediana}{MAD}$
#
# gdzie:
#
# X - wynik w drugiej turze kandydata
#
# mediana - mediana wyników kandydata w drugiej turze
#
# MAD - odchelenie bezwzględne mediany kandydata w drugiej turze

# %%
kandydat_A = "TRZASKOWSKI Rafał Kazimierz"
kandydat_B = "NAWROCKI Karol Tadeusz"

# %%
# mediana w grupie
df[kandydat_A + '_mediana_2'] = df.groupby('group_id')[kandydat_A+'_2'].transform('median')
df[kandydat_B + '_mediana_2'] = df.groupby('group_id')[kandydat_B+'_2'].transform('median')

# %%
# MAD w grupie
from scipy.stats import median_abs_deviation
def mad(series):
    """Median Absolute Deviation"""
    return median_abs_deviation(series)

df[kandydat_A + "_MAD_2"] = df.groupby("group_id")[kandydat_A+'_2'].transform(mad)
df[kandydat_B + "_MAD_2"] = df.groupby("group_id")[kandydat_B+'_2'].transform(mad)

# %%
# wspolczynnik k

# %%
df[kandydat_A +'_k_analiza_1'] = (df[kandydat_A +'_2'] - df[kandydat_A + '_mediana_2'])/df[kandydat_A + '_MAD_2']
df[kandydat_B +'_k_analiza_1'] = (df[kandydat_B +'_2'] - df[kandydat_B + '_mediana_2'])/df[kandydat_B + '_MAD_2']

# %%
k = 3

# %%
kandydat_A, sum(df[kandydat_A +'_k_analiza_1']>k)
# Out:
# ('TRZASKOWSKI Rafał Kazimierz', 2794)

# %%
kandydat_B, sum(df[kandydat_B +'_k_analiza_1']>k)
# Out:
# ('NAWROCKI Karol Tadeusz', 2015)

# %%
k = 2

# %%
kandydat_A, sum(df[kandydat_A +'_k_analiza_1']>k)
# Out:
# ('TRZASKOWSKI Rafał Kazimierz', 4551)

# %%
kandydat_B, sum(df[kandydat_B +'_k_analiza_1']>k)
# Out:
# ('NAWROCKI Karol Tadeusz', 3750)

# %% [markdown]
# ## WYNIKI:
# Dla k=2, takich komisji, w których "za duże" poparcie ma Nawrocki jest 3750, a Trzaskowski 4551.

# %% [markdown]
# Przykładowa grupa, w której są komisje gdzie obaj kandydaci mają "nadmierne" poparcie. Jak widać wysokie K wynika tylko i wyłącznie z rozmiaru komisji. Im większa komisja, tym większa szansa na anomalię wykrytą w ten sposób.

# %%
df[df['group_id']==1568]
# Out:
#     Teryt Gminy  Nr komisji       Gmina_1  TRZASKOWSKI Rafał Kazimierz_1  \
# 45      20103.0           1  gm. Gromadka                          306.0
# 46      20103.0           2  gm. Gromadka                           47.0
# 47      20103.0           3  gm. Gromadka                           45.0
# 48      20103.0           4  gm. Gromadka                           60.0
# 49      20103.0           5  gm. Gromadka                           49.0
# 50      20103.0           6  gm. Gromadka                           52.0
#
#     NAWROCKI Karol Tadeusz_1       Gmina_2  TRZASKOWSKI Rafał Kazimierz_2  \
# 45                     312.0  gm. Gromadka                          423.0
# 46                     208.0  gm. Gromadka                          108.0
# 47                      59.0  gm. Gromadka                           73.0
# 48                      91.0  gm. Gromadka                           85.0
# 49                      64.0  gm. Gromadka                           87.0
# 50                     111.0  gm. Gromadka                           96.0
#
#     NAWROCKI Karol Tadeusz_2         Gmina  TERYT gminy  Numer Kod pocztowy  \
# 45                     570.0  gm. Gromadka      20103.0      1       59-706
# 46                     354.0  gm. Gromadka      20103.0      2       59-706
# 47                     132.0  gm. Gromadka      20103.0      3       59-706
# 48                     167.0  gm. Gromadka      20103.0      4       59-706
# 49                     158.0  gm. Gromadka      20103.0      5       59-706
# 50                     187.0  gm. Gromadka      20103.0      6       59-706
#
#    Typ obszaru  Wyborcy    kod  group_id  liczba komisji w grupie  \
# 45        wieś   1628.0  59706      1568                        6
# 46        wieś    770.0  59706      1568                        6
# 47        wieś    305.0  59706      1568                        6
# 48        wieś    431.0  59706      1568                        6
# 49        wieś    420.0  59706      1568                        6
# 50        wieś    436.0  59706      1568                        6
#
#     TRZASKOWSKI Rafał Kazimierz_mediana_2  NAWROCKI Karol Tadeusz_mediana_2  \
# 45                                   91.5                             177.0
# 46                                   91.5                             177.0
# 47                                   91.5                             177.0
# 48                                   91.5                             177.0
# 49                                   91.5                             177.0
# 50                                   91.5                             177.0
#
#     TRZASKOWSKI Rafał Kazimierz_MAD_2  NAWROCKI Karol Tadeusz_MAD_2  \
# 45                               11.5                          32.0
# 46                               11.5                          32.0
# 47                               11.5                          32.0
# 48                               11.5                          32.0
# 49                               11.5                          32.0
# 50                               11.5                          32.0
#
#     TRZASKOWSKI Rafał Kazimierz_k_analiza_1  \
# 45                                28.826087
# 46                                 1.434783
# 47                                -1.608696
# 48                                -0.565217
# 49                                -0.391304
# 50                                 0.391304
#
#     NAWROCKI Karol Tadeusz_k_analiza_1
# 45                            12.28125
# 46                             5.53125
# 47                            -1.40625
# 48                            -0.31250
# 49                            -0.59375
# 50                             0.31250

# %%
# zapisz anomalie na korzyść kandydatów do późniejszego sumowania
df[kandydat_A + "_anomalia_1"] = df[kandydat_A +'_k_analiza_1']>2
df[kandydat_B + "_anomalia_1"] = df[kandydat_B +'_k_analiza_1']>2

# %% [markdown]
# ## 2. Nadmierny względny wzrost poparcia dla Karola Nawrockiego między pierwszą a drugą turą, w porównaniu do odpowiedniego wzrostu poparcia dla Rafała Trzaskowskiego w tej samej grupie lokalnej;

# %% [markdown]
# Nie podano wprost jak to było obliczone więc kolejno:
# 1. Dla danego kandydata obliczam względny wzrost między pierwszą a drugą turą (dzieląc wynik z drugiej przez wynik z pierwszej)
# 2. Następnie odnoszę go do wzrostu drugiego kandydata - liczę różnicę między względnymi wzrostami.
# 3. Dalej tak jak w pierwszym typie anomalii - dla tych różnic liczę medianę grupy, MAD grupy oraz odchylenie k w komisji.

# %%
# wzgledny wzrost między pierwszą a drugą turą
df[kandydat_A+ '_wzrost'] = df[kandydat_A+'_2']/df[kandydat_A+'_1']
df[kandydat_B+ '_wzrost'] = df[kandydat_B+'_2']/df[kandydat_B+'_1']

# %%
# roznica wzglednego wzrostu miedzy kandydatami
df['roz_wzr_' + kandydat_A] =  df[kandydat_A + '_wzrost']  - df[kandydat_B + '_wzrost'] # wzrost A w porównaniu do B
df['roz_wzr_' + kandydat_B] =  df[kandydat_B + '_wzrost']  - df[kandydat_A + '_wzrost'] # wzrost B w porównaniu do A

# %%
# mediana i mad różnicy względnego wzrostu poparcia
df['roz_wzr_' + kandydat_A +'_mediana'] = df.groupby('group_id')['roz_wzr_' + kandydat_A].transform('median')
df['roz_wzr_' + kandydat_A + '_MAD'] =    df.groupby('group_id')['roz_wzr_' + kandydat_A].transform(mad)

# %%
df['roz_wzr_' + kandydat_B +'_mediana'] = df.groupby('group_id')['roz_wzr_' + kandydat_B].transform('median')
df['roz_wzr_' + kandydat_B + '_MAD'] =    df.groupby('group_id')['roz_wzr_' + kandydat_B].transform(mad)

# %%
df[kandydat_A +'_k_analiza_2'] = (df['roz_wzr_' + kandydat_A] - df['roz_wzr_' + kandydat_A +'_mediana'])/df['roz_wzr_' + kandydat_A + '_MAD']

# %%
df[kandydat_B +'_k_analiza_2'] = (df['roz_wzr_' + kandydat_B] - df['roz_wzr_' + kandydat_B +'_mediana'])/df['roz_wzr_' + kandydat_B + '_MAD']

# %%
k = 3

# %%
kandydat_A, sum(df[kandydat_A +'_k_analiza_2']>k)
# Out:
# ('TRZASKOWSKI Rafał Kazimierz', 2106)

# %%
kandydat_B, sum(df[kandydat_B +'_k_analiza_2']>k)
# Out:
# ('NAWROCKI Karol Tadeusz', 1669)

# %%
k = 2

# %%
kandydat_A, sum(df[kandydat_A +'_k_analiza_2']>k)
# Out:
# ('TRZASKOWSKI Rafał Kazimierz', 3552)

# %%
kandydat_B, sum(df[kandydat_B +'_k_analiza_2']>k)
# Out:
# ('NAWROCKI Karol Tadeusz', 3127)

# %% [markdown]
# ## WYNIKI:
#
# "Nadmierny" względny wzrost poparcia dla Trzaskowskiego odnotowano w 3552 komisjach
#
# "Nadmierny" względny wzrost poparcia dla Nawrockiego odnotowano w 3127 komisjach

# %% [markdown]
# W tej samej grupie co dla analizy 1 mamy jeden obwód z "Nadmiernym względnym wzrostem poparcia" na korzyść Trzaskowskiego (komisja nr 2):

# %%
df[df['group_id']==1568]
# Out:
#     Teryt Gminy  Nr komisji       Gmina_1  TRZASKOWSKI Rafał Kazimierz_1  \
# 45      20103.0           1  gm. Gromadka                          306.0
# 46      20103.0           2  gm. Gromadka                           47.0
# 47      20103.0           3  gm. Gromadka                           45.0
# 48      20103.0           4  gm. Gromadka                           60.0
# 49      20103.0           5  gm. Gromadka                           49.0
# 50      20103.0           6  gm. Gromadka                           52.0
#
#     NAWROCKI Karol Tadeusz_1       Gmina_2  TRZASKOWSKI Rafał Kazimierz_2  \
# 45                     312.0  gm. Gromadka                          423.0
# 46                     208.0  gm. Gromadka                          108.0
# 47                      59.0  gm. Gromadka                           73.0
# 48                      91.0  gm. Gromadka                           85.0
# 49                      64.0  gm. Gromadka                           87.0
# 50                     111.0  gm. Gromadka                           96.0
#
#     NAWROCKI Karol Tadeusz_2         Gmina  TERYT gminy  Numer Kod pocztowy  \
# 45                     570.0  gm. Gromadka      20103.0      1       59-706
# 46                     354.0  gm. Gromadka      20103.0      2       59-706
# 47                     132.0  gm. Gromadka      20103.0      3       59-706
# 48                     167.0  gm. Gromadka      20103.0      4       59-706
# 49                     158.0  gm. Gromadka      20103.0      5       59-706
# 50                     187.0  gm. Gromadka      20103.0      6       59-706
#
#    Typ obszaru  Wyborcy    kod  group_id  liczba komisji w grupie  \
# 45        wieś   1628.0  59706      1568                        6
# 46        wieś    770.0  59706      1568                        6
# 47        wieś    305.0  59706      1568                        6
# 48        wieś    431.0  59706      1568                        6
# 49        wieś    420.0  59706      1568                        6
# 50        wieś    436.0  59706      1568                        6
#
#     TRZASKOWSKI Rafał Kazimierz_mediana_2  NAWROCKI Karol Tadeusz_mediana_2  \
# 45                                   91.5                             177.0
# 46                                   91.5                             177.0
# 47                                   91.5                             177.0
# 48                                   91.5                             177.0
# 49                                   91.5                             177.0
# 50                                   91.5                             177.0
#
#     TRZASKOWSKI Rafał Kazimierz_MAD_2  NAWROCKI Karol Tadeusz_MAD_2  \
# 45                               11.5                          32.0
# 46                               11.5                          32.0
# 47                               11.5                          32.0
# 48                               11.5                          32.0
# 49                               11.5                          32.0
# 50                               11.5                          32.0
#
#     TRZASKOWSKI Rafał Kazimierz_k_analiza_1  \
# 45                                28.826087
# 46                                 1.434783
# 47                                -1.608696
# 48                                -0.565217
# 49                                -0.391304
# 50                                 0.391304
#
#     NAWROCKI Karol Tadeusz_k_analiza_1  \
# 45                            12.28125
# 46                             5.53125
# 47                            -1.40625
# 48                            -0.31250
# 49                            -0.59375
# 50                             0.31250
#
#     TRZASKOWSKI Rafał Kazimierz_anomalia_1  NAWROCKI Karol Tadeusz_anomalia_1  \
# 45                                    True                               True
# 46                                   False                               True
# 47                                   False                              False
# 48                                   False                              False
# 49                                   False                              False
# 50                                   False                              False
#
#     TRZASKOWSKI Rafał Kazimierz_wzrost  NAWROCKI Karol Tadeusz_wzrost  \
# 45                            1.382353                       1.826923
# 46                            2.297872                       1.701923
# 47                            1.622222                       2.237288
# 48                            1.416667                       1.835165
# 49                            1.775510                       2.468750
# 50                            1.846154                       1.684685
#
#     roz_wzr_TRZASKOWSKI Rafał Kazimierz  roz_wzr_NAWROCKI Karol Tadeusz  \
# 45                            -0.444570                        0.444570
# 46                             0.595949                       -0.595949
# 47                            -0.615066                        0.615066
# 48                            -0.418498                        0.418498
# 49                            -0.693240                        0.693240
# 50                             0.161469                       -0.161469
#
#     roz_wzr_TRZASKOWSKI Rafał Kazimierz_mediana  \
# 45                                    -0.431534
# 46                                    -0.431534
# 47                                    -0.431534
# 48                                    -0.431534
# 49                                    -0.431534
# 50                                    -0.431534
#
#     roz_wzr_TRZASKOWSKI Rafał Kazimierz_MAD  \
# 45                                 0.222619
# 46                                 0.222619
# 47                                 0.222619
# 48                                 0.222619
# 49                                 0.222619
# 50                                 0.222619
#
#     roz_wzr_NAWROCKI Karol Tadeusz_mediana  \
# 45                                0.431534
# 46                                0.431534
# 47                                0.431534
# 48                                0.431534
# 49                                0.431534
# 50                                0.431534
#
#     roz_wzr_NAWROCKI Karol Tadeusz_MAD  \
# 45                            0.222619
# 46                            0.222619
# 47                            0.222619
# 48                            0.222619
# 49                            0.222619
# 50                            0.222619
#
#     TRZASKOWSKI Rafał Kazimierz_k_analiza_2  \
# 45                                -0.058557
# 46                                 4.615441
# 47                                -0.824422
# 48                                 0.058557
# 49                                -1.175578
# 50                                 2.663762
#
#     NAWROCKI Karol Tadeusz_k_analiza_2
# 45                            0.058557
# 46                           -4.615441
# 47                            0.824422
# 48                           -0.058557
# 49                            1.175578
# 50                           -2.663762

# %%
# anomalia na korzyść kandydata
df[kandydat_A + "_anomalia_2"] = df[kandydat_A +'_k_analiza_2']>2
df[kandydat_B + "_anomalia_2"] = df[kandydat_B +'_k_analiza_2']>2

# %% [markdown]
# ## 3. Komisje, w których Nawrocki uzyskał więcej głosów niż Trzaskowski w drugiej turze, mimo że mediana wyników w grupie wskazywała na przewagę Trzaskowskiego;

# %% [markdown]
# 1. Sprawdzamy, w których grupach dany kandydat miał większą medianę
# 2. Sumujemy komisje, w których wygrał kandydat A mimo, że większą medianę miał kandydat B i na odwrót.

# %%
# wieksza mediana w grupie
df['wieksza_mediana_' + kandydat_A] = (df[kandydat_A + '_mediana_2'] >  df[kandydat_B + '_mediana_2']).astype(bool)
df['wieksza_mediana_' + kandydat_B] = (df[kandydat_B + '_mediana_2'] >  df[kandydat_A + '_mediana_2']).astype(bool)

# %%
# na korzyść kandydat A, czyli większą medianę miał B, a więcej głosów dostał A.
kandydat_A, sum(df['wieksza_mediana_' + kandydat_B] & (df[kandydat_A + '_2'] > df[kandydat_B + '_2']))
# Out:
# ('TRZASKOWSKI Rafał Kazimierz', 2608)

# %%
kandydat_B, sum(df['wieksza_mediana_' + kandydat_A] & (df[kandydat_B + '_2'] > df[kandydat_A + '_2']))
# Out:
# ('NAWROCKI Karol Tadeusz', 1843)

# %% [markdown]
# ## WYNIKI:
# W grupach, w których większą medianę miał Nawrocki, było 2608 komisji, w których wyższy wynik uzyskał Trzaskowski.
#
# W grupach, w których większą medianę miał Trzaskowski, było 1843 komisji, w których wyższy wyniki uzyskał Nawrocki.

# %% [markdown]
# Przykładowo:
#
# W komisji 13 gdzie w drugiej turze głosowało.. 13 osób, Trzaskowski uzyskał większy wynik (8 do 5), mimo że w grupie obejmującej kod pocztowy 59-730 większą medianę miał Nawrocki (344 vs 158).

# %%
df[df['group_id']==1572]
# Out:
#     Teryt Gminy  Nr komisji           Gmina_1  TRZASKOWSKI Rafał Kazimierz_1  \
# 34      20102.0          11   gm. Bolesławiec                           81.0
# 51      20104.0           1  gm. Nowogrodziec                           85.0
# 52      20104.0           2  gm. Nowogrodziec                          102.0
# 53      20104.0           3  gm. Nowogrodziec                           72.0
# 54      20104.0           4  gm. Nowogrodziec                           72.0
# 55      20104.0           5  gm. Nowogrodziec                          134.0
# 56      20104.0           6  gm. Nowogrodziec                           60.0
# 57      20104.0           7  gm. Nowogrodziec                          246.0
# 58      20104.0           8  gm. Nowogrodziec                          239.0
# 59      20104.0           9  gm. Nowogrodziec                           80.0
# 60      20104.0          10  gm. Nowogrodziec                          155.0
# 61      20104.0          11  gm. Nowogrodziec                          161.0
# 62      20104.0          12  gm. Nowogrodziec                           29.0
# 63      20104.0          13  gm. Nowogrodziec                            4.0
# 64      20104.0          14  gm. Nowogrodziec                            5.0
#
#     NAWROCKI Karol Tadeusz_1           Gmina_2  TRZASKOWSKI Rafał Kazimierz_2  \
# 34                     220.0   gm. Bolesławiec                          131.0
# 51                     139.0  gm. Nowogrodziec                          158.0
# 52                     207.0  gm. Nowogrodziec                          161.0
# 53                      61.0  gm. Nowogrodziec                          118.0
# 54                     255.0  gm. Nowogrodziec                          175.0
# 55                     217.0  gm. Nowogrodziec                          211.0
# 56                      81.0  gm. Nowogrodziec                          109.0
# 57                     369.0  gm. Nowogrodziec                          415.0
# 58                     297.0  gm. Nowogrodziec                          394.0
# 59                      86.0  gm. Nowogrodziec                          127.0
# 60                     325.0  gm. Nowogrodziec                          262.0
# 61                     179.0  gm. Nowogrodziec                          274.0
# 62                      35.0  gm. Nowogrodziec                           45.0
# 63                       3.0  gm. Nowogrodziec                            8.0
# 64                       4.0  gm. Nowogrodziec                            6.0
#
#     NAWROCKI Karol Tadeusz_2             Gmina  TERYT gminy  Numer  \
# 34                     344.0   gm. Bolesławiec      20102.0     11
# 51                     283.0  gm. Nowogrodziec      20104.0      1
# 52                     349.0  gm. Nowogrodziec      20104.0      2
# 53                     133.0  gm. Nowogrodziec      20104.0      3
# 54                     495.0  gm. Nowogrodziec      20104.0      4
# 55                     395.0  gm. Nowogrodziec      20104.0      5
# 56                     161.0  gm. Nowogrodziec      20104.0      6
# 57                     662.0  gm. Nowogrodziec      20104.0      7
# 58                     520.0  gm. Nowogrodziec      20104.0      8
# 59                     168.0  gm. Nowogrodziec      20104.0      9
# 60                     606.0  gm. Nowogrodziec      20104.0     10
# 61                     346.0  gm. Nowogrodziec      20104.0     11
# 62                      76.0  gm. Nowogrodziec      20104.0     12
# 63                       5.0  gm. Nowogrodziec      20104.0     13
# 64                       7.0  gm. Nowogrodziec      20104.0     14
#
#    Kod pocztowy    Typ obszaru  Wyborcy    kod  group_id  \
# 34       59-730           wieś    772.0  59730      1572
# 51       59-730           wieś    797.0  59730      1572
# 52       59-730           wieś    878.0  59730      1572
# 53       59-730           wieś    400.0  59730      1572
# 54       59-730           wieś   1107.0  59730      1572
# 55       59-730           wieś   1012.0  59730      1572
# 56       59-730           wieś    435.0  59730      1572
# 57       59-730         miasto   1731.0  59730      1572
# 58       59-730         miasto   1497.0  59730      1572
# 59       59-730           wieś    497.0  59730      1572
# 60       59-730           wieś   1424.0  59730      1572
# 61       59-730           wieś   1060.0  59730      1572
# 62       59-730  miasto i wieś    196.0  59730      1572
# 63       59-730         miasto     70.0  59730      1572
# 64       59-730         miasto     49.0  59730      1572
#
#     liczba komisji w grupie  TRZASKOWSKI Rafał Kazimierz_mediana_2  \
# 34                       15                                  158.0
# 51                       15                                  158.0
# 52                       15                                  158.0
# 53                       15                                  158.0
# 54                       15                                  158.0
# 55                       15                                  158.0
# 56                       15                                  158.0
# 57                       15                                  158.0
# 58                       15                                  158.0
# 59                       15                                  158.0
# 60                       15                                  158.0
# 61                       15                                  158.0
# 62                       15                                  158.0
# 63                       15                                  158.0
# 64                       15                                  158.0
#
#     NAWROCKI Karol Tadeusz_mediana_2  TRZASKOWSKI Rafał Kazimierz_MAD_2  \
# 34                             344.0                               53.0
# 51                             344.0                               53.0
# 52                             344.0                               53.0
# 53                             344.0                               53.0
# 54                             344.0                               53.0
# 55                             344.0                               53.0
# 56                             344.0                               53.0
# 57                             344.0                               53.0
# 58                             344.0                               53.0
# 59                             344.0                               53.0
# 60                             344.0                               53.0
# 61                             344.0                               53.0
# 62                             344.0                               53.0
# 63                             344.0                               53.0
# 64                             344.0                               53.0
#
#     NAWROCKI Karol Tadeusz_MAD_2  TRZASKOWSKI Rafał Kazimierz_k_analiza_1  \
# 34                         176.0                                -0.509434
# 51                         176.0                                 0.000000
# 52                         176.0                                 0.056604
# 53                         176.0                                -0.754717
# 54                         176.0                                 0.320755
# 55                         176.0                                 1.000000
# 56                         176.0                                -0.924528
# 57                         176.0                                 4.849057
# 58                         176.0                                 4.452830
# 59                         176.0                                -0.584906
# 60                         176.0                                 1.962264
# 61                         176.0                                 2.188679
# 62                         176.0                                -2.132075
# 63                         176.0                                -2.830189
# 64                         176.0                                -2.867925
#
#     NAWROCKI Karol Tadeusz_k_analiza_1  \
# 34                            0.000000
# 51                           -0.346591
# 52                            0.028409
# 53                           -1.198864
# 54                            0.857955
# 55                            0.289773
# 56                           -1.039773
# 57                            1.806818
# 58                            1.000000
# 59                           -1.000000
# 60                            1.488636
# 61                            0.011364
# 62                           -1.522727
# 63                           -1.926136
# 64                           -1.914773
#
#     TRZASKOWSKI Rafał Kazimierz_anomalia_1  NAWROCKI Karol Tadeusz_anomalia_1  \
# 34                                   False                              False
# 51                                   False                              False
# 52                                   False                              False
# 53                                   False                              False
# 54                                   False                              False
# 55                                   False                              False
# 56                                   False                              False
# 57                                    True                              False
# 58                                    True                              False
# 59                                   False                              False
# 60                                   False                              False
# 61                                    True                              False
# 62                                   False                              False
# 63                                   False                              False
# 64                                   False                              False
#
#     TRZASKOWSKI Rafał Kazimierz_wzrost  NAWROCKI Karol Tadeusz_wzrost  \
# 34                            1.617284                       1.563636
# 51                            1.858824                       2.035971
# 52                            1.578431                       1.685990
# 53                            1.638889                       2.180328
# 54                            2.430556                       1.941176
# 55                            1.574627                       1.820276
# 56                            1.816667                       1.987654
# 57                            1.686992                       1.794038
# 58                            1.648536                       1.750842
# 59                            1.587500                       1.953488
# 60                            1.690323                       1.864615
# 61                            1.701863                       1.932961
# 62                            1.551724                       2.171429
# 63                            2.000000                       1.666667
# 64                            1.200000                       1.750000
#
#     roz_wzr_TRZASKOWSKI Rafał Kazimierz  roz_wzr_NAWROCKI Karol Tadeusz  \
# 34                             0.053648                       -0.053648
# 51                            -0.177148                        0.177148
# 52                            -0.107559                        0.107559
# 53                            -0.541439                        0.541439
# 54                             0.489379                       -0.489379
# 55                            -0.245650                        0.245650
# 56                            -0.170988                        0.170988
# 57                            -0.107046                        0.107046
# 58                            -0.102306                        0.102306
# 59                            -0.365988                        0.365988
# 60                            -0.174293                        0.174293
# 61                            -0.231098                        0.231098
# 62                            -0.619704                        0.619704
# 63                             0.333333                       -0.333333
# 64                            -0.550000                        0.550000
#
#     roz_wzr_TRZASKOWSKI Rafał Kazimierz_mediana  \
# 34                                    -0.174293
# 51                                    -0.174293
# 52                                    -0.174293
# 53                                    -0.174293
# 54                                    -0.174293
# 55                                    -0.174293
# 56                                    -0.174293
# 57                                    -0.174293
# 58                                    -0.174293
# 59                                    -0.174293
# 60                                    -0.174293
# 61                                    -0.174293
# 62                                    -0.174293
# 63                                    -0.174293
# 64                                    -0.174293
#
#     roz_wzr_TRZASKOWSKI Rafał Kazimierz_MAD  \
# 34                                 0.071987
# 51                                 0.071987
# 52                                 0.071987
# 53                                 0.071987
# 54                                 0.071987
# 55                                 0.071987
# 56                                 0.071987
# 57                                 0.071987
# 58                                 0.071987
# 59                                 0.071987
# 60                                 0.071987
# 61                                 0.071987
# 62                                 0.071987
# 63                                 0.071987
# 64                                 0.071987
#
#     roz_wzr_NAWROCKI Karol Tadeusz_mediana  \
# 34                                0.174293
# 51                                0.174293
# 52                                0.174293
# 53                                0.174293
# 54                                0.174293
# 55                                0.174293
# 56                                0.174293
# 57                                0.174293
# 58                                0.174293
# 59                                0.174293
# 60                                0.174293
# 61                                0.174293
# 62                                0.174293
# 63                                0.174293
# 64                                0.174293
#
#     roz_wzr_NAWROCKI Karol Tadeusz_MAD  \
# 34                            0.071987
# 51                            0.071987
# 52                            0.071987
# 53                            0.071987
# 54                            0.071987
# 55                            0.071987
# 56                            0.071987
# 57                            0.071987
# 58                            0.071987
# 59                            0.071987
# 60                            0.071987
# 61                            0.071987
# 62                            0.071987
# 63                            0.071987
# 64                            0.071987
#
#     TRZASKOWSKI Rafał Kazimierz_k_analiza_2  \
# 34                                 3.166427
# 51                                -0.039659
# 52                                 0.927031
# 53                                -5.100200
# 54                                 9.219379
# 55                                -0.991251
# 56                                 0.045913
# 57                                 0.934156
# 58                                 1.000000
# 59                                -2.662933
# 60                                 0.000000
# 61                                -0.789101
# 62                                -6.187423
# 63                                 7.051674
# 64                                -5.219126
#
#     NAWROCKI Karol Tadeusz_k_analiza_2  \
# 34                           -3.166427
# 51                            0.039659
# 52                           -0.927031
# 53                            5.100200
# 54                           -9.219379
# 55                            0.991251
# 56                           -0.045913
# 57                           -0.934156
# 58                           -1.000000
# 59                            2.662933
# 60                            0.000000
# 61                            0.789101
# 62                            6.187423
# 63                           -7.051674
# 64                            5.219126
#
#     TRZASKOWSKI Rafał Kazimierz_anomalia_2  NAWROCKI Karol Tadeusz_anomalia_2  \
# 34                                    True                              False
# 51                                   False                              False
# 52                                   False                              False
# 53                                   False                               True
# 54                                    True                              False
# 55                                   False                              False
# 56                                   False                              False
# 57                                   False                              False
# 58                                   False                              False
# 59                                   False                               True
# 60                                   False                              False
# 61                                   False                              False
# 62                                   False                               True
# 63                                    True                              False
# 64                                   False                               True
#
#     wieksza_mediana_TRZASKOWSKI Rafał Kazimierz  \
# 34                                        False
# 51                                        False
# 52                                        False
# 53                                        False
# 54                                        False
# 55                                        False
# 56                                        False
# 57                                        False
# 58                                        False
# 59                                        False
# 60                                        False
# 61                                        False
# 62                                        False
# 63                                        False
# 64                                        False
#
#     wieksza_mediana_NAWROCKI Karol Tadeusz
# 34                                    True
# 51                                    True
# 52                                    True
# 53                                    True
# 54                                    True
# 55                                    True
# 56                                    True
# 57                                    True
# 58                                    True
# 59                                    True
# 60                                    True
# 61                                    True
# 62                                    True
# 63                                    True
# 64                                    True

# %%
# anomalie na korzysc
df[kandydat_A + '_anomalia_3'] = df['wieksza_mediana_' + kandydat_B] & (df[kandydat_A + '_2'] > df[kandydat_B + '_2']) 
df[kandydat_B + '_anomalia_3'] = df['wieksza_mediana_' + kandydat_A] & (df[kandydat_B + '_2'] > df[kandydat_A + '_2'])

# %% [markdown]
# ## 4. Kandydat otrzymał mniej głosów w drugiej turze niż w pierwszej

# %%
kandydat_A, sum(df[kandydat_A + '_2']<df[kandydat_A + '_1'])
# Out:
# ('TRZASKOWSKI Rafał Kazimierz', 128)

# %%
kandydat_B, sum(df[kandydat_B + '_2']<df[kandydat_B + '_1'])
# Out:
# ('NAWROCKI Karol Tadeusz', 112)

# %% [markdown]
# W 128 komisjach Trzaskowski uzyskał mniej głosów w drugiej turze niż w pierwszej.
#
# W 112 komisjach Nawrocki uzyskał mniej głosó w drugiej turze niż w pierwszej.

# %% [markdown]
# Przykładowe anomalie na korzyść Trzaskowskiego:

# %%
df[df[kandydat_B + '_2']<df[kandydat_B + '_1']].head()
# Out:
#      Teryt Gminy  Nr komisji             Gmina_1  \
# 125      20202.0          23      m. Dzierżoniów
# 321      20602.0           8           m. Kowary
# 360      20608.0           7       gm. Podgórzyn
# 375      20701.0          10    m. Kamienna Góra
# 636      21002.0           5  m. Świeradów-Zdrój
#
#      TRZASKOWSKI Rafał Kazimierz_1  NAWROCKI Karol Tadeusz_1  \
# 125                            8.0                       9.0
# 321                           22.0                      25.0
# 360                            4.0                      15.0
# 375                            6.0                       7.0
# 636                            7.0                       9.0
#
#                 Gmina_2  TRZASKOWSKI Rafał Kazimierz_2  \
# 125      m. Dzierżoniów                           12.0
# 321           m. Kowary                           26.0
# 360       gm. Podgórzyn                            7.0
# 375    m. Kamienna Góra                           10.0
# 636  m. Świeradów-Zdrój                            5.0
#
#      NAWROCKI Karol Tadeusz_2               Gmina  TERYT gminy  Numer  \
# 125                       7.0      m. Dzierżoniów      20202.0     23
# 321                      19.0           m. Kowary      20602.0      8
# 360                      13.0       gm. Podgórzyn      20608.0      7
# 375                       2.0    m. Kamienna Góra      20701.0     10
# 636                       8.0  m. Świeradów-Zdrój      21002.0      5
#
#     Kod pocztowy Typ obszaru  Wyborcy    kod  group_id  \
# 125       58-200      miasto     47.0  58200      1516
# 321       58-530      miasto     48.0  58530      1543
# 360       58-564        wieś     55.0  58564      1546
# 375       58-400      miasto     37.0  58400      1537
# 636       59-850      miasto     21.0  59850      2714
#
#      liczba komisji w grupie  TRZASKOWSKI Rafał Kazimierz_mediana_2  \
# 125                       24                                  383.5
# 321                       10                                  329.0
# 360                       16                                  483.5
# 375                       23                                  145.0
# 636                       11                                   98.0
#
#      NAWROCKI Karol Tadeusz_mediana_2  TRZASKOWSKI Rafał Kazimierz_MAD_2  \
# 125                             302.0                               74.0
# 321                             216.5                              161.0
# 360                             300.5                              309.5
# 375                             154.0                               86.0
# 636                             211.0                               73.0
#
#      NAWROCKI Karol Tadeusz_MAD_2  TRZASKOWSKI Rafał Kazimierz_k_analiza_1  \
# 125                          49.0                                -5.020270
# 321                          91.0                                -1.881988
# 360                         111.0                                -1.539580
# 375                          89.0                                -1.569767
# 636                          53.0                                -1.273973
#
#      NAWROCKI Karol Tadeusz_k_analiza_1  \
# 125                           -6.020408
# 321                           -2.170330
# 360                           -2.590090
# 375                           -1.707865
# 636                           -3.830189
#
#      TRZASKOWSKI Rafał Kazimierz_anomalia_1  \
# 125                                   False
# 321                                   False
# 360                                   False
# 375                                   False
# 636                                   False
#
#      NAWROCKI Karol Tadeusz_anomalia_1  TRZASKOWSKI Rafał Kazimierz_wzrost  \
# 125                              False                            1.500000
# 321                              False                            1.181818
# 360                              False                            1.750000
# 375                              False                            1.666667
# 636                              False                            0.714286
#
#      NAWROCKI Karol Tadeusz_wzrost  roz_wzr_TRZASKOWSKI Rafał Kazimierz  \
# 125                       0.777778                             0.722222
# 321                       0.760000                             0.421818
# 360                       0.866667                             0.883333
# 375                       0.285714                             1.380952
# 636                       0.888889                            -0.174603
#
#      roz_wzr_NAWROCKI Karol Tadeusz  \
# 125                       -0.722222
# 321                       -0.421818
# 360                       -0.883333
# 375                       -1.380952
# 636                        0.174603
#
#      roz_wzr_TRZASKOWSKI Rafał Kazimierz_mediana  \
# 125                                    -0.235163
# 321                                    -0.304523
# 360                                    -0.250784
# 375                                    -0.276397
# 636                                    -0.271933
#
#      roz_wzr_TRZASKOWSKI Rafał Kazimierz_MAD  \
# 125                                 0.133249
# 321                                 0.200856
# 360                                 0.187909
# 375                                 0.203887
# 636                                 0.407785
#
#      roz_wzr_NAWROCKI Karol Tadeusz_mediana  \
# 125                                0.235163
# 321                                0.304523
# 360                                0.250784
# 375                                0.276397
# 636                                0.271933
#
#      roz_wzr_NAWROCKI Karol Tadeusz_MAD  \
# 125                            0.133249
# 321                            0.200856
# 360                            0.187909
# 375                            0.203887
# 636                            0.407785
#
#      TRZASKOWSKI Rafał Kazimierz_k_analiza_2  \
# 125                                 7.184909
# 321                                 3.616234
# 360                                 6.035457
# 375                                 8.128783
# 636                                 0.238679
#
#      NAWROCKI Karol Tadeusz_k_analiza_2  \
# 125                           -7.184909
# 321                           -3.616234
# 360                           -6.035457
# 375                           -8.128783
# 636                           -0.238679
#
#      TRZASKOWSKI Rafał Kazimierz_anomalia_2  \
# 125                                    True
# 321                                    True
# 360                                    True
# 375                                    True
# 636                                   False
#
#      NAWROCKI Karol Tadeusz_anomalia_2  \
# 125                              False
# 321                              False
# 360                              False
# 375                              False
# 636                              False
#
#      wieksza_mediana_TRZASKOWSKI Rafał Kazimierz  \
# 125                                         True
# 321                                         True
# 360                                         True
# 375                                        False
# 636                                        False
#
#      wieksza_mediana_NAWROCKI Karol Tadeusz  \
# 125                                   False
# 321                                   False
# 360                                   False
# 375                                    True
# 636                                    True
#
#      TRZASKOWSKI Rafał Kazimierz_anomalia_3  NAWROCKI Karol Tadeusz_anomalia_3
# 125                                   False                              False
# 321                                   False                              False
# 360                                   False                               True
# 375                                    True                              False
# 636                                   False                              False

# %%
# Anomalie na korzysc
df[kandydat_A + '_anomalia_4'] = df[kandydat_B + '_2']<df[kandydat_B + '_1']
df[kandydat_B + '_anomalia_4'] = df[kandydat_A + '_2']<df[kandydat_A + '_1']

# %%
df.replace([np.inf, -np.inf], np.nan, inplace=True)
df = df.dropna()

# %% [markdown]
# # Sumowanie anomalii

# %% [markdown]
# # Na korzyść Trzaskowskiego

# %%
df[kandydat_A + '_razem_anomali_na_korzysc'] = df[[
    kandydat_A + '_anomalia_1', 
    kandydat_A + '_anomalia_2',
    kandydat_A + '_anomalia_3',
    kandydat_A + '_anomalia_4']].sum(axis=1)

# %%
kandydat_A, sum(df[kandydat_A + '_razem_anomali_na_korzysc']>=1)
# Out:
# ('TRZASKOWSKI Rafał Kazimierz', 9386)

# %%
kandydat_A, sum(df[kandydat_A + '_razem_anomali_na_korzysc']>=2)
# Out:
# ('TRZASKOWSKI Rafał Kazimierz', 1276)

# %%
kandydat_A, sum(df[kandydat_A + '_razem_anomali_na_korzysc']>=3)
# Out:
# ('TRZASKOWSKI Rafał Kazimierz', 43)

# %%
kandydat_A, sum(df[kandydat_A + '_razem_anomali_na_korzysc']>=4)
# Out:
# ('TRZASKOWSKI Rafał Kazimierz', 3)

# %%
# Komisje z wszystkimi czterma anomaliami
df[df[kandydat_A + '_razem_anomali_na_korzysc']>=4]
# Out:
#        Teryt Gminy  Nr komisji        Gmina_1  TRZASKOWSKI Rafał Kazimierz_1  \
# 4994       60903.0           4    gm. Bychawa                           89.0
# 12294     140706.0           1  gm. Magnuszew                          105.0
# 24999     261207.0           4    gm. Staszów                          143.0
#
#        NAWROCKI Karol Tadeusz_1        Gmina_2  TRZASKOWSKI Rafał Kazimierz_2  \
# 4994                      174.0    gm. Bychawa                          260.0
# 12294                     285.0  gm. Magnuszew                          467.0
# 24999                     224.0    gm. Staszów                          360.0
#
#        NAWROCKI Karol Tadeusz_2          Gmina  TERYT gminy  Numer  \
# 4994                      163.0    gm. Bychawa      60903.0      4
# 12294                     193.0  gm. Magnuszew     140706.0      1
# 24999                     209.0    gm. Staszów     261207.0      4
#
#       Kod pocztowy Typ obszaru  Wyborcy    kod  group_id  \
# 4994        23-100      miasto    659.0  23100       522
# 12294       26-910        wieś    878.0  26910       630
# 24999       28-200      miasto    808.0  28200       662
#
#        liczba komisji w grupie  TRZASKOWSKI Rafał Kazimierz_mediana_2  \
# 4994                        20                                   64.0
# 12294                       10                                  102.0
# 24999                       29                                  123.0
#
#        NAWROCKI Karol Tadeusz_mediana_2  TRZASKOWSKI Rafał Kazimierz_MAD_2  \
# 4994                              203.5                               33.5
# 12294                             221.0                               42.5
# 24999                             294.0                               97.0
#
#        NAWROCKI Karol Tadeusz_MAD_2  TRZASKOWSKI Rafał Kazimierz_k_analiza_1  \
# 4994                           68.0                                 5.850746
# 12294                          36.5                                 8.588235
# 24999                          57.0                                 2.443299
#
#        NAWROCKI Karol Tadeusz_k_analiza_1  \
# 4994                            -0.595588
# 12294                           -0.767123
# 24999                           -1.491228
#
#        TRZASKOWSKI Rafał Kazimierz_anomalia_1  \
# 4994                                     True
# 12294                                    True
# 24999                                    True
#
#        NAWROCKI Karol Tadeusz_anomalia_1  TRZASKOWSKI Rafał Kazimierz_wzrost  \
# 4994                               False                            2.921348
# 12294                              False                            4.447619
# 24999                              False                            2.517483
#
#        NAWROCKI Karol Tadeusz_wzrost  roz_wzr_TRZASKOWSKI Rafał Kazimierz  \
# 4994                        0.936782                             1.984567
# 12294                       0.677193                             3.770426
# 24999                       0.933036                             1.584447
#
#        roz_wzr_NAWROCKI Karol Tadeusz  \
# 4994                        -1.984567
# 12294                       -3.770426
# 24999                       -1.584447
#
#        roz_wzr_TRZASKOWSKI Rafał Kazimierz_mediana  \
# 4994                                      0.283991
# 12294                                     0.106758
# 24999                                     0.020685
#
#        roz_wzr_TRZASKOWSKI Rafał Kazimierz_MAD  \
# 4994                                  0.291965
# 12294                                 0.364758
# 24999                                 0.200502
#
#        roz_wzr_NAWROCKI Karol Tadeusz_mediana  \
# 4994                                -0.283991
# 12294                               -0.106758
# 24999                               -0.020685
#
#        roz_wzr_NAWROCKI Karol Tadeusz_MAD  \
# 4994                             0.291965
# 12294                            0.364758
# 24999                            0.200502
#
#        TRZASKOWSKI Rafał Kazimierz_k_analiza_2  \
# 4994                                  5.824589
# 12294                                10.044104
# 24999                                 7.799246
#
#        NAWROCKI Karol Tadeusz_k_analiza_2  \
# 4994                            -5.824589
# 12294                          -10.044104
# 24999                           -7.799246
#
#        TRZASKOWSKI Rafał Kazimierz_anomalia_2  \
# 4994                                     True
# 12294                                    True
# 24999                                    True
#
#        NAWROCKI Karol Tadeusz_anomalia_2  \
# 4994                               False
# 12294                              False
# 24999                              False
#
#        wieksza_mediana_TRZASKOWSKI Rafał Kazimierz  \
# 4994                                         False
# 12294                                        False
# 24999                                        False
#
#        wieksza_mediana_NAWROCKI Karol Tadeusz  \
# 4994                                     True
# 12294                                    True
# 24999                                    True
#
#        TRZASKOWSKI Rafał Kazimierz_anomalia_3  \
# 4994                                     True
# 12294                                    True
# 24999                                    True
#
#        NAWROCKI Karol Tadeusz_anomalia_3  \
# 4994                               False
# 12294                              False
# 24999                              False
#
#        TRZASKOWSKI Rafał Kazimierz_anomalia_4  \
# 4994                                     True
# 12294                                    True
# 24999                                    True
#
#        NAWROCKI Karol Tadeusz_anomalia_4  \
# 4994                               False
# 12294                              False
# 24999                              False
#
#        TRZASKOWSKI Rafał Kazimierz_razem_anomali_na_korzysc
# 4994                                                   4
# 12294                                                  4
# 24999                                                  4

# %% [markdown]
# # Na korzyść Nawrockiego

# %%
df[kandydat_B + '_razem_anomali_na_korzysc'] = df[[
    kandydat_B + '_anomalia_1', 
    kandydat_B + '_anomalia_2',
    kandydat_B + '_anomalia_3',
    kandydat_B + '_anomalia_4']].sum(axis=1)

# %%
kandydat_B, sum(df[kandydat_B + '_razem_anomali_na_korzysc']>=1)
# Out:
# ('NAWROCKI Karol Tadeusz', 8028)

# %%
kandydat_B, sum(df[kandydat_B + '_razem_anomali_na_korzysc']>=2)
# Out:
# ('NAWROCKI Karol Tadeusz', 689)

# %%
kandydat_B, sum(df[kandydat_B + '_razem_anomali_na_korzysc']>=3)
# Out:
# ('NAWROCKI Karol Tadeusz', 42)

# %%
kandydat_B, sum(df[kandydat_B + '_razem_anomali_na_korzysc']>=4)
# Out:
# ('NAWROCKI Karol Tadeusz', 2)

# %%
# Komisje z 4 anomaliami, "widać Kraków"
df[df[kandydat_B + '_razem_anomali_na_korzysc']>=4]
# Out:
#        Teryt Gminy  Nr komisji                Gmina_1  \
# 11295     126101.0          95              m. Kraków
# 16574     161105.0           9  gm. Strzelce Opolskie
#
#        TRZASKOWSKI Rafał Kazimierz_1  NAWROCKI Karol Tadeusz_1  \
# 11295                          550.0                     218.0
# 16574                          311.0                     107.0
#
#                      Gmina_2  TRZASKOWSKI Rafał Kazimierz_2  \
# 11295              m. Kraków                          540.0
# 16574  gm. Strzelce Opolskie                          223.0
#
#        NAWROCKI Karol Tadeusz_2                  Gmina  TERYT gminy  Numer  \
# 11295                    1132.0              m. Kraków     126101.0     95
# 16574                     416.0  gm. Strzelce Opolskie     161105.0      9
#
#       Kod pocztowy Typ obszaru  Wyborcy    kod  group_id  \
# 11295       31-346      miasto   1943.0  31346       691
# 16574       47-100      miasto    957.0  47100      1408
#
#        liczba komisji w grupie  TRZASKOWSKI Rafał Kazimierz_mediana_2  \
# 11295                       14                                  814.5
# 16574                       34                                  230.5
#
#        NAWROCKI Karol Tadeusz_mediana_2  TRZASKOWSKI Rafał Kazimierz_MAD_2  \
# 11295                             424.5                              174.0
# 16574                             174.5                              101.0
#
#        NAWROCKI Karol Tadeusz_MAD_2  TRZASKOWSKI Rafał Kazimierz_k_analiza_1  \
# 11295                          46.0                                -1.577586
# 16574                          60.0                                -0.074257
#
#        NAWROCKI Karol Tadeusz_k_analiza_1  \
# 11295                           15.380435
# 16574                            4.025000
#
#        TRZASKOWSKI Rafał Kazimierz_anomalia_1  \
# 11295                                   False
# 16574                                   False
#
#        NAWROCKI Karol Tadeusz_anomalia_1  TRZASKOWSKI Rafał Kazimierz_wzrost  \
# 11295                               True                            0.981818
# 16574                               True                            0.717042
#
#        NAWROCKI Karol Tadeusz_wzrost  roz_wzr_TRZASKOWSKI Rafał Kazimierz  \
# 11295                       5.192661                            -4.210842
# 16574                       3.887850                            -3.170809
#
#        roz_wzr_NAWROCKI Karol Tadeusz  \
# 11295                        4.210842
# 16574                        3.170809
#
#        roz_wzr_TRZASKOWSKI Rafał Kazimierz_mediana  \
# 11295                                    -0.059256
# 16574                                    -0.656285
#
#        roz_wzr_TRZASKOWSKI Rafał Kazimierz_MAD  \
# 11295                                 0.158571
# 16574                                 0.240919
#
#        roz_wzr_NAWROCKI Karol Tadeusz_mediana  \
# 11295                                0.059256
# 16574                                0.656285
#
#        roz_wzr_NAWROCKI Karol Tadeusz_MAD  \
# 11295                            0.158571
# 16574                            0.240919
#
#        TRZASKOWSKI Rafał Kazimierz_k_analiza_2  \
# 11295                               -26.181205
# 16574                               -10.437204
#
#        NAWROCKI Karol Tadeusz_k_analiza_2  \
# 11295                           26.181205
# 16574                           10.437204
#
#        TRZASKOWSKI Rafał Kazimierz_anomalia_2  \
# 11295                                   False
# 16574                                   False
#
#        NAWROCKI Karol Tadeusz_anomalia_2  \
# 11295                               True
# 16574                               True
#
#        wieksza_mediana_TRZASKOWSKI Rafał Kazimierz  \
# 11295                                         True
# 16574                                         True
#
#        wieksza_mediana_NAWROCKI Karol Tadeusz  \
# 11295                                   False
# 16574                                   False
#
#        TRZASKOWSKI Rafał Kazimierz_anomalia_3  \
# 11295                                   False
# 16574                                   False
#
#        NAWROCKI Karol Tadeusz_anomalia_3  \
# 11295                               True
# 16574                               True
#
#        TRZASKOWSKI Rafał Kazimierz_anomalia_4  \
# 11295                                   False
# 16574                                   False
#
#        NAWROCKI Karol Tadeusz_anomalia_4  \
# 11295                               True
# 16574                               True
#
#        TRZASKOWSKI Rafał Kazimierz_razem_anomali_na_korzysc  \
# 11295                                                  0
# 16574                                                  0
#
#        NAWROCKI Karol Tadeusz_razem_anomali_na_korzysc
# 11295                                                4
# 16574                                                4
